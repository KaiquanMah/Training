# %% [markdown]
# # Welcome to the Tuning Speech notebook!
#
# Please click the ► button above to get started. As the blue highlight moves to the next section, read that section to understand what will happen, then click ► to proceed. The first section loads a test set and a test function we will use throughout the lab.

# %%
# !pip install --upgrade google-cloud-speech

# %%
audio_map = """367-130732-0000 LOBSTERS AND LOBSTERS
367-130732-0001 WHEN IS A LOBSTER NOT A LOBSTER WHEN IT IS A CRAYFISH
367-130732-0002 THIS QUESTION AND ANSWER MIGHT WELL GO INTO THE PRIMER OF INFORMATION FOR THOSE WHO COME TO SAN FRANCISCO FROM THE EAST FOR WHAT IS CALLED A LOBSTER IN SAN FRANCISCO IS NOT A LOBSTER AT ALL BUT A CRAYFISH
367-130732-0004 A BOOK COULD BE WRITTEN ABOUT THIS RESTAURANT AND THEN ALL WOULD NOT BE TOLD FOR ALL ITS SECRETS CAN NEVER BE KNOWN
367-130732-0005 IT WAS HERE THAT MOST MAGNIFICENT DINNERS WERE ARRANGED IT WAS HERE THAT EXTRAORDINARY DISHES WERE CONCOCTED BY CHEFS OF WORLD WIDE FAME IT WAS HERE THAT LOBSTER A LA NEWBERG REACHED ITS HIGHEST PERFECTION AND THIS IS THE RECIPE THAT WAS FOLLOWED WHEN IT WAS PREPARED IN THE DELMONICO
367-130732-0006 LOBSTER A LA NEWBERG
367-130732-0007 ONE POUND OF LOBSTER MEAT ONE TEASPOONFUL OF BUTTER ONE HALF PINT OF CREAM YOLKS OF FOUR EGGS ONE WINE GLASS OF SHERRY LOBSTER FAT
367-130732-0008 PUT THIS IN A DOUBLE BOILER AND LET COOK UNTIL THICK STIRRING CONSTANTLY
367-130732-0009 SERVE IN A CHAFING DISH WITH THIN SLICES OF DRY TOAST
367-130732-0010 KING OF SHELL FISH
367-130732-0011 ONE HAS TO COME TO SAN FRANCISCO TO PARTAKE OF THE KING OF SHELL FISH THE MAMMOTH PACIFIC CRAB
367-130732-0012 I SAY COME TO SAN FRANCISCO ADVISEDLY FOR WHILE THE CRAB IS FOUND ALL ALONG THE COAST IT IS PREPARED NOWHERE SO DELICIOUSLY AS IN SAN FRANCISCO
367-130732-0013 GOBEY'S PASSED WITH THE FIRE AND THE LITTLE RESTAURANT BEARING HIS NAME AND IN CHARGE OF HIS WIDOW IN UNION SQUARE AVENUE HAS NOT ATTAINED THE FAME OF THE OLD PLACE
367-130732-0014 IT IS POSSIBLE THAT SHE KNOWS THE SECRET OF PREPARING CRAB AS IT WAS PREPARED IN THE GOBEY'S OF BEFORE THE FIRE BUT HIS PRESTIGE DID NOT DESCEND TO HER
367-130732-0015 GOBEY'S CRAB STEW
367-130732-0016 TAKE THE MEAT OF ONE LARGE CRAB SCRAPING OUT ALL OF THE FAT FROM THE SHELL
367-130732-0017 SOAK THE CRAB MEAT IN THE SHERRY TWO HOURS BEFORE COOKING
367-130732-0018 CHOP FINE THE ONION SWEET PEPPER AND TOMATO WITH THE ROSEMARY
367-130732-0019 HEAT THIS IN A STEWPAN AND WHEN SIMMERING ADD THE SHERRY AND CRAB MEAT AND LET ALL COOK TOGETHER WITH A SLOW FIRE FOR EIGHT MINUTES
367-130732-0020 SERVE IN A CHAFING DISH WITH TOASTED CRACKERS OR THIN SLICES OF TOASTED BREAD
367-130732-0021 LOBSTER IN MINIATURE
367-130732-0022 SO FAR IT HAS BEEN USED MOSTLY FOR GARNISHMENT OF OTHER DISHES AND IT IS ONLY RECENTLY THAT THE HOF BRAU HAS BEEN MAKING A SPECIALTY OF THEM
367-130732-0023 ALL OF THE BETTER CLASS RESTAURANTS HOWEVER WILL SERVE THEM IF YOU ORDER THEM
367-130732-0024 THIS IS THE RECIPE FOR EIGHT PEOPLE AND IT IS WELL WORTH TRYING IF YOU ARE GIVING A DINNER OF IMPORTANCE
367-130732-0025 BISQUE OF CRAWFISH
367-130732-0026 TAKE 30 CRAWFISH FROM WHICH REMOVE THE GUT CONTAINING THE GALL IN THE FOLLOWING MANNER TAKE FIRM HOLD OF THE CRAWFISH WITH THE LEFT HAND SO AS TO AVOID BEING PINCHED BY ITS CLAWS WITH THE THUMB AND FOREFINGER OF THE RIGHT HAND PINCH THE EXTREME END OF THE CENTRAL FIN OF THE TAIL AND WITH A SUDDEN JERK THE GUT WILL BE WITHDRAWN
367-130732-0027 MINCE OR CUT INTO SMALL DICE A CARROT AN ONION ONE HEAD OF CELERY AND A FEW PARSLEY ROOTS AND TO THESE ADD A BAY LEAF A SPRIG OF THYME A LITTLE MINIONETTE PEPPER AND TWO OUNCES OF BUTTER
367-130732-0028 PUT THESE INGREDIENTS INTO A STEWPAN AND FRY THEM 10 MINUTES THEN THROW IN THE CRAWFISH AND POUR ON THEM HALF A BOTTLE OF FRENCH WHITE WINE
367-130732-0029 ALLOW THIS TO BOIL AND THEN ADD A QUART OF STRONG CONSOMME AND LET ALL CONTINUE BOILING FOR HALF AN HOUR
367-130732-0030 PICK OUT THE CRAWFISH AND STRAIN THE BROTH THROUGH A NAPKIN BY PRESSURE INTO A BASIN IN ORDER TO EXTRACT ALL THE ESSENCE FROM THE VEGETABLES
367-130732-0031 PICK THE SHELLS OFF 25 OF THE CRAWFISH TAILS TRIM THEM NEATLY AND SET THEM ASIDE UNTIL WANTED
367-130732-0032 RESERVE SOME OF THE SPAWN ALSO HALF OF THE BODY SHELLS WITH WHICH TO MAKE THE CRAWFISH BUTTER TO FINISH THE SOUP
367-130732-0033 THIS BUTTER IS MADE AS FOLLOWS PLACE THE SHELLS ON A BAKING SHEET IN THE OVEN TO DRY LET THE SHELLS COOL AND THEN POUND THEM IN A MORTAR WITH A LITTLE LOBSTER CORAL AND FOUR OUNCES OF FRESH BUTTER THOROUGHLY BRUISING THE WHOLE TOGETHER SO AS TO MAKE A FINE PASTE
s2-130732-0000 Three hours before cooking pour the sherry over the lobster meat and let it stand until ready to cook
s2-130732-0001 Heat the butter and stir in with the lobster and wine then place this in a stewpan or chafing dish and cook for eight minutes
s2-130732-0002 Have the yolks of eggs well beaten and add to them the cream and lobster fat stir well and then stir in a teaspoonful of flour
s2-130732-0003 Serve in a chafing dish with thin slices of dry toast
1-130732-0000 When is a lobster not a lobster When it is a crayfish This question and answer might well go into the primer of information for those who come to San Francisco from the East
1-130732-0001 for what is called a lobster in San Francisco is not a lobster at all but a crayfish The true lobster is not found in the Pacific along the California coast and so far efforts at transplanting have not been successful
4-130732-0000 Probably nowhere in San Francisco could one get lobster better served than in the Old Delmonico restaurant of the days before the fire
4-130732-0001 A book could be written about this restaurant and then all would not be told for all its secrets can never be known
s3-130732-0000 Take the meat of one large crab scraping out all of the fat from the shell
s3-130732-0001 Chop fine the onion sweet pepper and tomato with the rosemary Mash the clove of garlic rubbing thoroughly in a mortar and on this put the butter and flour mixing well together and gradually adding the salt and minionette pepper and stir in two tablespoonfuls of cream
s3-130732-0002 The full flavor of the crawfish is best obtained in a bisque and the best recipe for this is by the famous chef Francatelli who boasts having been the head of the cuisine of Queen Victoria
s3-130732-0003 In New York City they have what they are pleased to call "Lobster Palaces" but there is not a restaurant in that great metropolis that could approach the Delmonico of San Francisco in its splendid service and its cuisine arrangements
s3-130732-0004 In the pre-fire days there were many places which paid especial attention to the cooking of the crab among them being the Cobweb Palace"""

from google.cloud import speech_v1p1beta1 as speech
import simple_wer_v2 as wer
from IPython.display import display, HTML, clear_output

client = speech.SpeechClient()
encoding = speech.types.RecognitionConfig.AudioEncoding

def recognize_all(name, dataset, config):
    results = HTML("<body><html><h1>Loading...</h1></body></html>")
    display(results)
    
    analysis = wer.SimpleWER(
        key_phrases=[phrase
                     for context in config.speech_contexts
                     for phrase in context.phrases],
        html_handler=wer.HighlightAlignedHtml,
        preprocess_handler=wer.RemoveCommentTxtPreprocess)
    

    for line in audio_map.splitlines():
        words = line.split()
        path = f"spls/gsp758/{dataset}/{words[0]}.wav"
        audio = speech.RecognitionAudio(uri=f"gs://{path}")
        response = client.recognize(config=config, audio=audio)
        hypothesis = "".join([result.alternatives[0].transcript
                              for result in response.results])
        reference = " ".join(words[1:])
        analysis.AddHypRef(hypothesis, reference,
                           f'<audio controls><source src="https://storage.cloud.google.com/{path}" type="audio/wav">{words[0]}</audio>')
    
    summary, details, keyphrases = analysis.GetSummaries()

    aligned_html = f"""<body><html>
<h1>{name}</h1>
<div>{summary}<br>{details}<br><b>{keyphrases}</b></div>
<table>{"".join(analysis.aligned_htmls)}</table>
</body></html>"""

    results = HTML(aligned_html)
    clear_output()
    display(results)

# %% [markdown]
# # Getting Started
#
# After running the sections above, we now have a method `#recognize_all` we can use to iterate, tuning the `speech_contexts` with each test to observe the effect on recognition quality.
#
# This method takes three arguments:
# 1. A name for the test
# 2. An enum value, specifying either the `"clean"` or `"noisy"` dataset. The two sets are identical, but we have applied a noise effect to the "noisy" set to simulate low-quality microphones and loud environments.
# 3. The [RecognitionConfig](https://cloud.google.com/speech-to-text/docs/reference/rest/v1p1beta1/RecognitionConfig) sent to the Speech API.
#
# Let's start with a baseline test to see what we're up against.

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
)

recognize_all("Baseline", "noisy", config)

# %% [markdown]
# # Evaluating Baseline Results
#
# Take a look at the results above. The highlighted text indicates errors in the Speech API results (green, strikethrough) versus the ground truth (yellow) defined at the beginning of this exercise.
#
# # Getting Started With Adaptation
#
# You're the expert now, and you need to pick out which errors from the baseline test are most important to good looking transcripts. Start adding these words and phrases to the "phrases" array below.
#
# Tip: Focus on important words like "lobster" as opposed to "is" or "a", unless you include these generic words in larger phrases like "put this in". Remember, we're biasing the Speech models and we want to be careful not to overbias. A few errors of missing "an" is probably better than turning every "and" into "an".
#
# Tip: Although you may not need them in this lab, be sure to check out Google's [phrase class tokens](https://cloud.google.com/speech-to-text/docs/class-tokens). These are special phrases you can apply to recognize classes of words. For example, `"$OPERAND"` will match numerical values like "1" (pronounce "one") and "200" (pronounced "two hundred"). You may notice the ground truth above uses a mix of numerals like "25" and spelled-out quantities like "four". These are stylistic decisions best ignored for the purposes of this lab, but a hint like "$OPERAND" can help standardize these formats, especially on shorter command-like utterances.
#
# # Ready? Let's get going.
# What words and phrases do you find are important to recipe transcripts? Add them to the "phrases" array below and click ► when you're ready. It will take a minute or so before the results show.

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
    speech_contexts= [
      {
          # insert phrases here, e.g. ["lobster", "San Francisco", "Gobey's"]
          "phrases": [],
      }
  ]
)

recognize_all("Your Key Phrases Here", "noisy", config)

# %% [markdown]
# # Evaluating Adaptation Results
#
# Once again take a look at the highlighted errors above. Do the results look better than the baseline?
#
# Note how the WER (word error rate) and error breakdowns have changed from the baseline. Are you getting a lower error rate overall?
#
# Also, since you added your key phrases, you'll now see an [F1 score](https://en.wikipedia.org/wiki/F1_score) and [Jaccard similarity](https://en.wikipedia.org/wiki/Jaccard_index) that indicate how well the Speech API is recognizing your key phrases. You want these scores to be as close to 1.0 as possible.
#
# # Tuning Adaptation Results
#
# Let's focus on maximizing these key phrase metrics. We've already hinted the phrases, but we can fine-tune the biasing further by using "boost". Look at the results above to identify which phrases are still not transcribing correctly.
#
# When you've found some, move them into separate context blocks to manually set the weight of each phrase. Make these changes in the template below, then run the section to see the new results.

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
    speech_contexts= [
      {
          # Copy your phrases from the previous section
          "phrases": [],
      },{
          # Which phrases are still not transcribing?
          # Move those phrases into a new context here.
          # Rememeber not to duplicate phrases across multiple contexts.
          "phrases": [],
          "boost": 10
      }
  ]
)

recognize_all("Tuning Key Phrases With Boost", "noisy", config)

# %% [markdown]
# # Continue Tuning
#
# How do the new metrics look? What about the transcripts?
#
# Be on the lookout for false-postives! These are phrases you boosted that show up in the transcript where they shouldn't have. If you find these, you'll want to try lowering the boost value to make Speech less aggressive in matching that phrase.
#
# You may also consider adding phrases to counter-balance the false-positives. For example, if you boost "we serve", you may start mis-transcribing "reserve". While you could add another phrase hint for "reserve", this is a dangerous game to play in case there is a third homophone. It is safer and easier to simply lower the boost value for "we serve" so that Speech will have a better chance of trasncribing all these phrases correctly.

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
    speech_contexts= [
      {
          "phrases": [],
      },{
          "phrases": [],
          "boost": 10
      },{
          # Did any of your boosted phrases produce false-positives?
          # Add a new context for these phrases--this time with a less aggressive boost.
          # Rememeber not to duplicate phrases across multiple contexts.
          "phrases": [],
          "boost": 5
      }
  ]
)

recognize_all("Tuning Key Phrases With Boost - Try 2", "noisy", config)

# %% [markdown]
# # That's it!
#
# You can right-click on the sections to copy and paste. Keep iterating, adding new contexts, adding new phrases, and adjusting the boost values to find the best results.

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
    speech_contexts= [
      # Fine tune until you are happy with the results
      {
          "phrases": [],
      },{
          "phrases": [],
          "boost": 11
      },{
          "phrases": [],
          "boost": 4.5
      },{
          "phrases": [],
          "boost": 1
      }
  ]
)

recognize_all("Tuning Key Phrases With Boost - Try 3", "noisy", config)

# %% [markdown]
# # Spoilers Ahead...
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# Below are some interesting results we found. After identifying our key phrases, we ran a test to evaluate these key phrases in both audio sets. First we see the clean audio with very little noise. It performs well minimal biasing:
# > matched 138 key phrases (162 in ref, 144 in hyp), jaccard similarity=0.82, F1=0.90
#
# Second we use the same minimal biasing on the noisy audio. As expected, it performs worse than the clean audio:
# > matched 123 key phrases (162 in ref, 132 in hyp), jaccard similarity=0.72, F1=0.84
#
# Finally, we spent some time iterating and tuning the adaptation. Amazingly, the noisy-but-highly-tuned audio set performed better than the clean-but-not-tuned set.
# > matched 144 key phrases (162 in ref, 156 in hyp), jaccard similarity=0.83, F1=0.91
#
# So what did we learn?
# Well, high quality audio is always best. When that's not an option, don't worry, because if you bias well for the phrases you care about, you may even get better results than if your audio was pristine.

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
    speech_contexts= [
      {
          "phrases": ["San Francisco", "Union Square", "New York"],
          "boost": 1
      },{
          "phrases": ["Gobey's", "Delmonico", "Francatelli", "Hof Brau"],
          "boost": 1
      },{
          "phrases": ["crayfish", "crawfish", "shell fish", "lobster", "lobsters", "lobster a la newberg",
                      "consomme", "a stewpan", "a chafing dish",
                      "teaspoonful", "teaspoonfuls",],
          "boost": 1
      },{
          "phrases": ["shell", "shells", "spawn", "claws", "fin", "yolks", "bisque", "sherry", "crab", "basin", "minionette",
                      "thin", "fine", "pound", "pounds", "ounce", "ounces", "one half",
                      "dice", "slice", "slices", "trim", "mince", "chop", "heat", "pick", "soak", "heat", "serve", "served", "reserve",
                      "pour", "take", "partake",                   
                      "preparing"],
          "boost": 1
      },{
          "phrases": ["allow this", "set them aside"],
          "boost": 1
      }
  ]
)

recognize_all("Clear Audio", "clean", config)

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
    speech_contexts= [
      {
          "phrases": ["San Francisco", "Union Square", "New York"],
          "boost": 1
      },{
          "phrases": ["Gobey's", "Delmonico", "Francatelli", "Hof Brau"],
          "boost": 1
      },{
          "phrases": ["crayfish", "crawfish", "shell fish", "lobster", "lobsters", "lobster a la newberg",
                      "consomme", "a stewpan", "a chafing dish",
                      "teaspoonful", "teaspoonfuls",],
          "boost": 1
      },{
          "phrases": ["shell", "shells", "spawn", "claws", "fin", "yolks", "bisque", "sherry", "crab", "basin", "minionette",
                      "thin", "fine", "pound", "pounds", "ounce", "ounces", "one half",
                      "dice", "slice", "slices", "trim", "mince", "chop", "heat", "pick", "soak", "heat", "serve", "served", "reserve",
                      "pour", "take", "partake",                   
                      "preparing"],
          "boost": 1
      },{
          "phrases": ["allow this", "set them aside"],
          "boost": 1
      }
  ]
)

recognize_all("Noisy Audio", "noisy", config)

# %%
config = speech.RecognitionConfig(
    encoding=encoding.LINEAR16,
    model="video",
    language_code="en-US",
    speech_contexts= [
      {
          "phrases": ["San Francisco", "Union Square", "New York"],
          "boost": 10
      },{
          "phrases": ["Gobey's", "Delmonico", "Francatelli", "Hof Brau"],
          "boost": 20
      },{
          "phrases": ["crayfish", "crawfish", "shell fish", "lobster", "lobsters", "lobster a la newberg",
                      "consomme", "a stewpan", "a chafing dish",
                      "teaspoonful", "teaspoonfuls",],
          "boost": 20
      },{
          "phrases": ["shell", "shells", "spawn", "claws", "fin", "yolks", "bisque", "sherry", "crab", "basin", "minionette",
                      "thin", "fine", "pound", "pounds", "ounce", "ounces", "one half",
                      "dice", "slice", "slices", "trim", "mince", "chop", "heat", "pick", "soak", "heat", "serve", "served", "reserve",
                      "pour", "take", "partake",                   
                      "preparing"],
          "boost": 10
      },{
          "phrases": ["allow this", "set them aside"]
      }
  ]
)

recognize_all("Noisy Audio - Tuned", "noisy", config)
