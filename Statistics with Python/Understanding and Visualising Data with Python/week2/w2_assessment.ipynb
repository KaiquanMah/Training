# %% [markdown]
# In this notebook, we'll ask you to find numerical summaries for a certain set of data. You will use the values of what you find in this assignment to answer questions in the quiz that follows (we've noted where specific values will be requested in the quiz, so that you can record them.)
#
# We'll also ask you to create some of the plots you have seen in previous lectures.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats
pd.set_option('display.max_columns', 100)

path = "nhanes_2015_2016.csv"

# %%
# First, you must import the data from the path given above
df = pd.read_csv(path) # using pandas, read in the csv data found at the url defined by 'path'

# %%
# Next, look at the 'head' of our DataFrame 'df'. 
df.head()    
    
# If you can't remember a function, open a previous notebook or video as a reference 
# or use your favorite search engine to look for a solution
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %% [markdown]
# How many rows can you see when you don't put an argument into the previous method?
# How many rows can you see if you use an int as an argument?
# Can you use a float as an argument?

# %%
df
#5735 rows × 28 columns
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# 5     83737     2.0     2.0     NaN       2         2        72         1
# 6     83741     1.0     NaN     8.0       1         1        22         4
# 7     83742     1.0     NaN     1.0       2         2        32         1
# 8     83743     NaN     NaN     NaN       2         1        18         5
# 9     83744     1.0     NaN     NaN       2         1        56         4
# 10    83747     1.0     NaN     1.0       1         1        46         3
# 11    83750     1.0     NaN     3.0       1         1        45         5
# ...

# %%
#cant use a float
df.head(3.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1b2bac266316> in <module>()
# ----> 1 df.head(3.0)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in head(self, n)
#    4640         """
#    4641
# -> 4642         return self.iloc[:n]
#    4643
#    4644     def tail(self, n=5):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2208
#    2209         if isinstance(key, slice):
# -> 2210             return self._get_slice_axis(key, axis=axis)
#    2211
# ...

# %%
#can use an int
df.head(3)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0      4.39   128.0    70.0   124.0    64.0   94.8  184.5    27.8    43.3
# 1      1.32   146.0    88.0   140.0    88.0   90.4  171.4    30.8    38.0
# 2      1.51   138.0    46.0   132.0    44.0   83.4  170.1    28.8    35.6
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
# Lets only consider the feature (or variable) 'BPXSY2'
bp = df['BPXSY2']

# %% [markdown]
# ## Numerical Summaries
# ### Find the mean (note this for the quiz that follows)

# %%
# What is the mean of 'BPXSY2'?
bp_mean = np.mean(bp)

# %% [markdown]
# In the method you used above, how are the rows of missing data treated?
# Are the excluded entirely? Are they counted as zeros? Something else?
# If you used a library function, try looking up the documentation using the code:
# ```
# help(function_you_used)
# ```
# For example:
# ```
# help(np.sum)
# ```

# %%
help(np.mean)
# Out:
# Help on function mean in module numpy.core.fromnumeric:
#
# mean(a, axis=None, dtype=None, out=None, keepdims=<no value>)
#     Compute the arithmetic mean along the specified axis.
#
#     Returns the average of the array elements.  The average is taken over
#     the flattened array by default, otherwise over the specified axis.
#     `float64` intermediate and return values are used for integer inputs.
#
#     Parameters
#     ----------
#     a : array_like
#         Array containing numbers whose mean is desired. If `a` is not an
#         array, a conversion is attempted.
#     axis : None or int or tuple of ints, optional
#         Axis or axes along which the means are computed. The default is to
#         compute the mean of the flattened array.
#
#         .. versionadded:: 1.7.0
#
#         If this is a tuple of ints, a mean is performed over multiple axes,
#         instead of a single axis or all the axes as before.
#     dtype : data-type, optional
# ...

# %%
#https://www.geeksforgeeks.org/python-numpy-nanmean-function/
#numpy.nanmean() function can be used to calculate the mean of array ignoring the NaN value

#seems that the usual np.mean takes into account NaNs

# %% [markdown]
# #### .dropna()
# To make sure we know that we aren't treating missing data in ways we don't want, lets go ahead and drop all the nans from our Series 'bp'

# %%
bp = bp.dropna()

# %% [markdown]
# ### Find the:
# * Median
# * Max
# * Min
# * Standard deviation
# * Variance
#
#
# You can implement any of these from base python (that is, without any of the imported packages), but there are simple and intuitively named functions in the numpy library for all of these. You could also use the fact that 'bp' is not just a list, but is a pandas.Series. You can find pandas.Series attributes and methods [here](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.Series.html)
#
# A large part of programming is being able to find the functions you need and to understand the documentation formatting so that you can implement the code yourself, so we highly encourage you to search the internet whenever you are unsure!

# %%
bp.describe()
# Out:
# count    5535.000000
# mean      124.783017
# std        18.527012
# min        84.000000
# 25%       112.000000
# 50%       122.000000
# 75%       134.000000
# max       238.000000
# Name: BPXSY2, dtype: float64

# %%
print('Min Systolic BP2 :', bp.min())
print('Mean Systolic BP2 :', bp.mean())
print('Median Systolic BP2 :', bp.median())
print('Variance Systolic BP2 :', bp.var())
print('SD Systolic BP2 :', bp.std())
print('Max Systolic BP2 :', bp.max())
# Out:
# Min Systolic BP2 : 84.0
# Mean Systolic BP2 : 124.78301716350497
# Median Systolic BP2 : 122.0
# Variance Systolic BP2 : 343.2501632839482
# SD Systolic BP2 : 18.527011720294997
# Max Systolic BP2 : 238.0

# %% [markdown]
# ### Example:
# Find the difference of an element in 'bp' compared with the previous element in 'bp'.

# %%
# Using the fact that 'bp' is a pd.Series object, can use the pd.Series method diff()
# call this method by: pd.Series.diff()
#by default - find diff between current row and previous row's value
diff_by_series_method = bp.diff() 

# note that this returns a pd.Series object, that is, it had an index associated with it
diff_by_series_method.values # only want to see the values, not the index and values
# Out:
# array([ nan,  16.,  -8., ...,  30., -40.,   8.])

# %%
# Now use the numpy library instead to find the same values
# np.diff(array)
diff_by_np_method = np.diff(bp)
diff_by_np_method
# note that this returns an 'numpy.ndarray', which has no index associated with it, and therefore ignores
# the nan we get by the Series method
# Out:
# array([ 16.,  -8.,   2., ...,  30., -40.,   8.])

# %%
# We could also implement this ourselves with some looping
diff_by_me = [] # create an empty list
for i in range(len(bp.values)-1): # iterate through the index values of bp
    diff = bp.values[i+1] - bp.values[i] # find the difference between an element and the previous element
    diff_by_me.append(diff) # append to out list
np.array(diff_by_me) # format as an np.array
# Out:
# array([ 16.,  -8.,   2., ...,  30., -40.,   8.])

# %% [markdown]
# ### Your turn (note these values for the quiz that follows)

# %%
# already completed above

# %%
# bp_median = 
# bp_median

# %%
# bp_max = 
# bp_max

# %%
# bp_min = 
# bp_min

# %%
# bp_std = 
# bp_std

# %%
# bp_var = 
# bp_var

# %% [markdown]
# ### How to find the interquartile range (note this value for the quiz that follows)
# This time we need to use the scipy.stats library that we imported above under the name 'stats'

# %%
bp_iqr = stats.iqr(bp) 
bp_iqr
# Out:
# 22.0

# %% [markdown]
# ## Visualizing the data
# Next we'll use what you have learned from the *Tables, Histograms, Boxplots in Python* video

# %%
# use the Series.describe() method to see some descriptive statistics of our Series 'bp'
bp_descriptive_stats = bp.describe()
bp_descriptive_stats
# Out:
# count    5535.000000
# mean      124.783017
# std        18.527012
# min        84.000000
# 25%       112.000000
# 50%       122.000000
# 75%       134.000000
# max       238.000000
# Name: BPXSY2, dtype: float64

# %%
# Make a histogram of our 'bp' data using the seaborn library we imported as 'sns'
sns.distplot(bp, kde=False).set(title='2nd Systolic Blood Pressure', xlabel='BPXSY2', ylabel='Count of People')
plt.show()

# %% [markdown]
# Is your histogram labeled and does it have a title?
# If not, try appending
# ```
# .set(title='your_title', xlabel='your_x_label', ylabel='your_y_label')
# ```
# or just
# ```
# .set(title='your_title')
# ```
# to your graphing function

# %%
sns.distplot(bp, kde=False).set(title='2nd Systolic Blood Pressure')
plt.show()

# %%
sns.hist(bp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-e4ec5ecfe81d> in <module>()
# ----> 1 sns.hist(bp)
#
# AttributeError: module 'seaborn' has no attribute 'hist'

# %%
sns.distplot(a=bp)

# %%
sns.distplot(a=bp).set(title="Histogram of bp")
# Out:
# [Text(0.5,1,'Histogram of bp')]

# %%
# Make a boxplot of our 'bp' data using the seaborn library. Make sure it has a title and labels!
sns.boxplot(bp).set(title='2nd Systolic Blood Pressure', xlabel='BPXSY2')
plt.show()
